# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from train import run, setup_hparams, setup_network

# %%
hps = setup_hparams()
hps['restore_epoch'] = 66
logger, net, optimizer, scheduler = setup_network(hps)
# Out:
# Network Restored!

# %%
run(net, logger, hps, optimizer, scheduler)
# Out:
# Training my_vgg on cuda:0  start_epoch:  67
# Epoch 68		Train Accuracy: 89.0209 %		Val Accuracy: 70.6325/70.6325 %		Train Loss: 0.0005 		Val Loss: 0.0201/0.0201
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-ea54c269a09b> in <module>
# ----> 1 run(net, logger, hps, optimizer, scheduler)
#
# ~/projects/face-facial/fer/train.py in run(net, logger, hps, optimizer, scheduler)
#      40     for epoch in range(start_epoch, hps['n_epochs']):
#      41
# ---> 42         acc_tr, loss_tr = train(net, trainloader, criterion, optimizer, scaler)
#      43         logger.loss_train.append(loss_tr)
#      44         logger.acc_train.append(acc_tr)
#
# ~/projects/face-facial/fer/utils/loops.py in train(net, dataloader, criterion, optimizer, scaler, Ncrop)
#      30             scaler.scale(loss).backward()
#      31
# ---> 32             scaler.step(optimizer)
#      33             scaler.update()
#      34             optimizer.zero_grad()
#
# ~/miniconda3/envs/torch_gpu/lib/python3.8/site-packages/torch/cuda/amp/grad_scaler.py in step(self, optimizer, *args, **kwargs)
#     337         assert len(optimizer_state["found_inf_per_device"]) > 0, "No inf checks were recorded for this optimizer."
#     338
# --> 339         retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#     340
#     341         optimizer_state["stage"] = OptState.STEPPED
#
# ~/miniconda3/envs/torch_gpu/lib/python3.8/site-packages/torch/cuda/amp/grad_scaler.py in _maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs)
#     283     def _maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs):
#     284         retval = None
# --> 285         if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#     286             retval = optimizer.step(*args, **kwargs)
#     287         return retval
#
# ~/miniconda3/envs/torch_gpu/lib/python3.8/site-packages/torch/cuda/amp/grad_scaler.py in <genexpr>(.0)
#     283     def _maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs):
#     284         retval = None
# --> 285         if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#     286             retval = optimizer.step(*args, **kwargs)
#     287         return retval
#
# KeyboardInterrupt:
